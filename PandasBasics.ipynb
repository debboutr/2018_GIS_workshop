# %% [markdown]
# # Exercise 1: Pandas

# %% [markdown]
# Objectives:
#    Create new cells in Jupyter notebook
#    Find help and documentation
#    Use Pandas selectors
#    Use Pandas methods adn attributes
#    Handle missing data

# %% [markdown]
# Jupyter Notebook tips:
#     Command Mode, Cells are Blue
#     Edit Mode, Cells are Green, Click on cell to go to edit mode, escape edit mode into command mode by clicking escape
#     When in Command Mode Add cells above (Click A) and cells below (Click B)
#     Use the ? to get documentation
#     Use tab to view attributes

# %% [markdown]
# Data: You will be using the EPA Great Lakes Restoraiton Initiative spreadsheet to query grants and fill in missing data
# Download data from: https://www.glri.us/projects/all-glri-projects-20170222.xlsx

# %% [markdown]
# ## Import Pandas Module

# %%
import pandas as pd

# %% [markdown]
# ## Access attributes, use help() and ? to access documentation

# %%
help(pd)
# Out:
# Help on package pandas:
#
# NAME
#     pandas
#
# DESCRIPTION
#     pandas - a powerful data analysis and manipulation library for Python
# ...
#
#     See http://pandas.pydata.org/ for full documentation. Otherwise, see the
#     docstrings of the various objects in the pandas namespace:
#
#     Series
#     DataFrame
#     Panel
#     Index
#     DatetimeIndex
#     HDFStore
#     bdate_range
#     date_range
#     read_csv
#     read_fwf
#     read_table
#     ols
#
# PACKAGE CONTENTS
#     _hash
#     _join
#     _period
#     _sparse
#     _testing
#     _version
#     _window
#     algos
#     api (package)
#     compat (package)
#     computation (package)
#     core (package)
#     formats (package)
#     hashtable
#     index
#     indexes (package)
#     info
#     io (package)
#     json
#     lib
#     msgpack (package)
#     parser
#     rpy (package)
#     sparse (package)
#     stats (package)
#     tests (package)
#     tools (package)
#     tseries (package)
#     tslib
# ...

# %%
pd.read_excel?

# %% [markdown]
# ## Read in your excel spreadhseet for this exercise

# %%
glri = pd.read_excel(r"C:\Users\jkrysa\Desktop\GLRI\DecemberUpdate\FY17Q4GLRI.xlsx")

# %% [markdown]
# ## View the dataframe and get to know your data

# %%
glri.head()
# default is to show first 5 rows, to view more put a number  in the tuple glri.head(10)
# Out:
#    ID Agency    Year  GLRI Amount Project Type  \
# 0   1    EPA  2010.0    1000000.0  New Project
# 1   2    EPA  2010.0     986299.0  New Project
# 2   3    EPA  2010.0    3376500.0  New Project
# 3   4    EPA  2010.0      85375.0  New Project
# 4   5    EPA  2011.0      85375.0     Increase
#
#                                        Project Title  \
# 0                        Cuyahoga County - Nearshore
# 1  Cover Crops and Conservation Tillage Reduce NP...
# 2                      Michigan LaMP and RAP Support
# 3  Tribal Capacity - 1854 Treaty Authority (Grand...
# 4  Tribal Capacity - 1854 Treaty Authority (Grand...
#
#                                Recipient Name Recipient Type  \
# 0        Ohio Environmental Protection Agency            NaN
# 1  Conservation Technology Information Center            NaN
# 2      Michigan Dept of Environmental Quality            NaN
# 3                              1854 Authority            NaN
# ...

# %%
glri.tail()
# Out:
#         ID Agency    Year  GLRI Amount  Project Type  \
# 4089  4090    FWS  2016.0       1600.0  Continuation
# 4090  4091    FWS  2016.0       1600.0  Continuation
# 4091  4092   NOAA  2016.0     194773.0   New Project
# 4092  4093   NOAA  2014.0      61800.0      Revision
# 4093  4094    NPS  2016.0      50000.0   New Project
#
#                                           Project Title  \
# 4089                     Piping plover monitoring in NY
# 4090                     Piping plover monitoring in NY
# 4091                                   Siskiwit Project
# 4092                   Great Lakes AOC Land Acquisition
# 4093  Conservation Legacy Fellow Program in Support ...
#
#                                   Recipient Name Recipient Type  \
# 4089                                        NYFO            NaN
# 4090                                        NYFO            NaN
# 4091           WI DOA, subrecipient Town of Bell            NaN
# ...

# %%
glri.columns
# Out:
# Index(['ID', 'Agency', 'Year', 'GLRI Amount', 'Project Type', 'Project Title',
#        'Recipient Name', 'Recipient Type', 'Project Description', 'Focus Area',
#        'Project Start Date', 'Project End Date', 'Affected States', 'Latitude',
#        'Longitude', 'Watersheds', 'Status', 'Tribal Nexus', 'Unnamed: 18'],
#       dtype='object')

# %%
glri.dtypes
# Out:
# ID                       int64
# Agency                  object
# Year                   float64
# GLRI Amount            float64
# Project Type            object
# Project Title           object
# Recipient Name          object
# Recipient Type          object
# Project Description     object
# Focus Area              object
# Project Start Date      object
# Project End Date        object
# Affected States         object
# Latitude               float64
# Longitude              float64
# Watersheds              object
# Status                  object
# Tribal Nexus            object
# Unnamed: 18             object
# dtype: object

# %%
glri.describe()
# Out:
#                ID         Year   GLRI Amount     Latitude    Longitude
# count  4094.00000  4086.000000  4.086000e+03  4012.000000  4012.000000
# mean   2047.50000  2013.223691  5.144093e+05    43.489976   -85.208687
# std    1181.98033     2.301378  1.267510e+06     1.876686     4.211608
# min       1.00000  2010.000000  0.000000e+00    38.880393   -95.011850
# 25%    1024.25000  2011.000000  7.490600e+04    42.031205   -87.863503
# 50%    2047.50000  2013.000000  1.900000e+05    43.013587   -85.011520
# 75%    3070.75000  2015.000000  4.995215e+05    44.849462   -83.056000
# max    4094.00000  2017.000000  2.911100e+07    48.163337   -41.621731

# %%
glri.shape
# Out:
# (4094, 19)

# %% [markdown]
# ## Use bracket notation to select data

# %%
glri['Year']
# Out:
# 0       2010.0
# 1       2010.0
# 2       2010.0
# 3       2010.0
# 4       2011.0
# 5       2012.0
# 6       2013.0
# 7       2015.0
# 8       2010.0
# 9       2010.0
# 10      2011.0
# 11      2012.0
# 12      2010.0
# 13      2010.0
# 14      2010.0
# 15      2010.0
# 16      2010.0
# 17      2010.0
# 18      2010.0
# 19      2010.0
# 20      2012.0
# 21      2013.0
# 22      2010.0
# 23      2011.0
# 24      2012.0
# 25      2013.0
# 26      2015.0
# 27      2010.0
# 28      2012.0
# 29      2010.0
#          ...
# 4064    2017.0
# 4065    2016.0
# 4066    2016.0
# 4067    2017.0
# 4068    2017.0
# 4069    2017.0
# 4070    2017.0
# 4071    2017.0
# 4072    2017.0
# 4073    2017.0
# 4074    2017.0
# 4075    2017.0
# 4076    2017.0
# 4077    2017.0
# 4078    2017.0
# 4079    2017.0
# 4080    2017.0
# 4081    2016.0
# 4082    2016.0
# 4083    2016.0
# 4084    2016.0
# 4085    2016.0
# 4086    2017.0
# 4087    2017.0
# 4088    2014.0
# 4089    2016.0
# 4090    2016.0
# ...

# %%
glri.Year
#As a convenience if the column name does not have spaces it's available through attribute notation
# Out:
# 0       2010.0
# 1       2010.0
# 2       2010.0
# 3       2010.0
# 4       2011.0
# 5       2012.0
# 6       2013.0
# 7       2015.0
# 8       2010.0
# 9       2010.0
# 10      2011.0
# 11      2012.0
# 12      2010.0
# 13      2010.0
# 14      2010.0
# 15      2010.0
# 16      2010.0
# 17      2010.0
# 18      2010.0
# 19      2010.0
# 20      2012.0
# 21      2013.0
# 22      2010.0
# 23      2011.0
# 24      2012.0
# 25      2013.0
# 26      2015.0
# 27      2010.0
# 28      2012.0
# 29      2010.0
#          ...
# 4064    2017.0
# 4065    2016.0
# 4066    2016.0
# 4067    2017.0
# 4068    2017.0
# 4069    2017.0
# 4070    2017.0
# 4071    2017.0
# 4072    2017.0
# 4073    2017.0
# 4074    2017.0
# 4075    2017.0
# 4076    2017.0
# 4077    2017.0
# 4078    2017.0
# 4079    2017.0
# 4080    2017.0
# 4081    2016.0
# 4082    2016.0
# 4083    2016.0
# 4084    2016.0
# 4085    2016.0
# 4086    2017.0
# 4087    2017.0
# 4088    2014.0
# 4089    2016.0
# 4090    2016.0
# ...

# %%
glri[glri.Year >= 2012]
#Perform queries within the bracket notation
# Out:
#         ID Agency    Year   GLRI Amount  Project Type  \
# 5        6    EPA  2012.0  8.537500e+04      Increase
# 6        7    EPA  2013.0  1.707500e+05      Increase
# 7        8    EPA  2015.0  2.500000e+04      Increase
# 11      12    EPA  2012.0  3.129690e+05      Increase
# 20      21    EPA  2012.0  7.750000e+04      Revision
# 21      22    EPA  2013.0  7.750000e+04      Increase
# 24      25    EPA  2012.0  6.550000e+04      Revision
# 25      26    EPA  2013.0  6.750000e+04      Increase
# 26      27    EPA  2015.0  3.750000e+04      Increase
# 28      29    EPA  2012.0  8.572310e+05      Increase
# 33      34    EPA  2013.0  9.215000e+05   New Project
# 34      35    EPA  2014.0  1.421497e+06      Increase
# 41      42    EPA  2013.0  5.623010e+05      Increase
# 54      55    EPA  2012.0  2.000000e+05   New Project
# 93      94    EPA  2012.0  3.010980e+05      Increase
# 94      95    EPA  2013.0  3.045850e+05      Increase
# ...

# %%
glri.Year.sort_values
# Out:
# <bound method Series.sort_values of 0       2010.0
# 1       2010.0
# 2       2010.0
# 3       2010.0
# 4       2011.0
# 5       2012.0
# 6       2013.0
# 7       2015.0
# 8       2010.0
# 9       2010.0
# 10      2011.0
# 11      2012.0
# 12      2010.0
# 13      2010.0
# 14      2010.0
# 15      2010.0
# 16      2010.0
# 17      2010.0
# 18      2010.0
# 19      2010.0
# 20      2012.0
# 21      2013.0
# 22      2010.0
# 23      2011.0
# 24      2012.0
# 25      2013.0
# 26      2015.0
# 27      2010.0
# 28      2012.0
# 29      2010.0
#          ...
# 4064    2017.0
# 4065    2016.0
# 4066    2016.0
# 4067    2017.0
# 4068    2017.0
# 4069    2017.0
# 4070    2017.0
# 4071    2017.0
# 4072    2017.0
# 4073    2017.0
# 4074    2017.0
# 4075    2017.0
# 4076    2017.0
# 4077    2017.0
# 4078    2017.0
# 4079    2017.0
# 4080    2017.0
# 4081    2016.0
# 4082    2016.0
# 4083    2016.0
# 4084    2016.0
# 4085    2016.0
# 4086    2017.0
# 4087    2017.0
# 4088    2014.0
# ...

# %%
glri.Year.value_counts()
# Out:
# 2010.0    698
# 2014.0    554
# 2016.0    518
# 2012.0    506
# 2011.0    503
# 2013.0    476
# 2015.0    456
# 2017.0    375
# Name: Year, dtype: int64

# %% [markdown]
# ## Lets clean up some missing data

# %%
glri.isnull().sum()
# Out:
# ID                        0
# Agency                    8
# Year                      8
# GLRI Amount               8
# Project Type              8
# Project Title             9
# Recipient Name           11
# Recipient Type         2311
# Project Description      37
# Focus Area                8
# Project Start Date       61
# Project End Date         66
# Affected States          39
# Latitude                 82
# Longitude                82
# Watersheds             1199
# Status                  881
# Tribal Nexus           1449
# Unnamed: 18            3611
# dtype: int64

# %%
glri.dropna(how='all').shape
# Out:
# (4094, 19)

# %%
glri.dropna(how='any').shape
# Out:
# (136, 19)

# %%
glri.dropna(subset=['Project Type'], how='any').shape
# Out:
# (4086, 19)

# %% [markdown]
# ## Lets clean up Latitude and Longitude fields

# %%
glri.Latitude.mean()
# Out:
# 43.489976405953996

# %%
glri.Latitude.min()
# Out:
# 38.880392999999998

# %%
glri.Latitude.max()
# Out:
# 48.163336999999999

# %%
#Creating a bounding box
glriLonOver = glri[glri['Longitude']>-65]
glriLonUnder = glri[glri['Longitude']<-100]
glriLatUnder = glri[glri['Latitude']<30]
glriLatOver = glri[glri['Latitude']>52]

# %% [markdown]
# ## Let's use some of the code we just learned to anwser some quesitons about the data

# %% [markdown]
# ## What are this data frame's column names?

# %%
glri.columns
# Out:
# Index(['ID', 'Agency', 'Year', 'GLRI Amount', 'Project Type', 'Project Title',
#        'Recipient Name', 'Recipient Type', 'Project Description', 'Focus Area',
#        'Project Start Date', 'Project End Date', 'Affected States', 'Latitude',
#        'Longitude', 'Watersheds', 'Status', 'Tribal Nexus', 'Unnamed: 18'],
#       dtype='object')

# %% [markdown]
# ## Which columns are numbers?

# %%
glri.dtypes
# Out:
# ID                       int64
# Agency                  object
# Year                   float64
# GLRI Amount            float64
# Project Type            object
# Project Title           object
# Recipient Name          object
# Recipient Type          object
# Project Description     object
# Focus Area              object
# Project Start Date      object
# Project End Date        object
# Affected States         object
# Latitude               float64
# Longitude              float64
# Watersheds              object
# Status                  object
# Tribal Nexus            object
# Unnamed: 18             object
# dtype: object

# %% [markdown]
# ## How many rows are in the data?

# %%
glri.shape
# Out:
# (4094, 19)

# %% [markdown]
# ## How many columns are found in the data?

# %%
glri.shape
# Out:
# (4094, 19)

# %% [markdown]
# ## How many unique agencies contribute to the data?

# %%
glri.Agency.unique()
# Out:
# array(['EPA', 'APHIS', 'ATSDR', 'BIA', 'CDC', 'FHWA', 'FS', 'FWS', 'MARAD',
#        'NOAA', 'NPS', 'NRCS', 'USACE', 'USCG', 'USGS', nan], dtype=object)

# %% [markdown]
# ## Which column has the most missing data?

# %%
glri.isnull().sum()
# Out:
# ID                        0
# Agency                    8
# Year                      8
# GLRI Amount               8
# Project Type              8
# Project Title             9
# Recipient Name           11
# Recipient Type         2311
# Project Description      37
# Focus Area                8
# Project Start Date       61
# Project End Date         66
# Affected States          39
# Latitude                 82
# Longitude                82
# Watersheds             1199
# Status                  881
# Tribal Nexus           1449
# Unnamed: 18            3611
# dtype: int64
